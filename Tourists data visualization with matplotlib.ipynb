# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
tourist_data=pd.read_csv('Train.csv')

# %%
tourist_data.head()
# Out:
#           ID         country age_group        travel_with  total_female  \
# 0     tour_0      SWIZERLAND     45-64  Friends/Relatives           1.0
# 1    tour_10  UNITED KINGDOM     25-44                NaN           1.0
# 2  tour_1000  UNITED KINGDOM     25-44              Alone           0.0
# 3  tour_1002  UNITED KINGDOM     25-44             Spouse           1.0
# 4  tour_1004           CHINA      1-24                NaN           1.0
#
#    total_male                         purpose     main_activity  \
# 0         1.0            Leisure and Holidays  Wildlife tourism
# 1         0.0            Leisure and Holidays  Cultural tourism
# 2         1.0  Visiting Friends and Relatives  Cultural tourism
# 3         1.0            Leisure and Holidays  Wildlife tourism
# 4         0.0            Leisure and Holidays  Wildlife tourism
#
#                     info_source tour_arrangement  ... package_transport_tz  \
# ...

# %%
tourist_data.shape
# Out:
# (4809, 23)

# %%
tourist_data.describe()
# Out:
#        total_female   total_male  night_mainland  night_zanzibar    total_cost
# count   4806.000000  4804.000000     4809.000000     4809.000000  4.809000e+03
# mean       0.926758     1.009575        8.488043        2.304429  8.114389e+06
# std        1.288242     1.138865       10.427624        4.227080  1.222490e+07
# min        0.000000     0.000000        0.000000        0.000000  4.900000e+04
# 25%        0.000000     1.000000        3.000000        0.000000  8.121750e+05
# 50%        1.000000     1.000000        6.000000        0.000000  3.397875e+06
# 75%        1.000000     1.000000       11.000000        4.000000  9.945000e+06
# max       49.000000    44.000000      145.000000       61.000000  9.953288e+07

# %%
tourist_data.country.value_counts()
# Out:
# UNITED STATES OF AMERICA    695
# UNITED KINGDOM              533
# ITALY                       393
# FRANCE                      280
# ZIMBABWE                    274
#                            ...
# MYANMAR                       1
# GEORGIA                       1
# ARGENTINA                     1
# CAPE VERDE                    1
# NIGER                         1
# Name: country, Length: 105, dtype: int64

# %%
tourist_data.country.value_counts().plot.bar(figsize=(25,5))
plt.title('distribution of frequency countries')
plt.ylabel('frequency')
# Out:
# Text(0, 0.5, 'frequency')

# %%
tourist_data.country.value_counts(normalize=True)*100
# Out:
# UNITED STATES OF AMERICA    14.452069
# UNITED KINGDOM              11.083385
# ITALY                        8.172177
# FRANCE                       5.822416
# ZIMBABWE                     5.697650
#                               ...
# MYANMAR                      0.020794
# GEORGIA                      0.020794
# ARGENTINA                    0.020794
# CAPE VERDE                   0.020794
# NIGER                        0.020794
# Name: country, Length: 105, dtype: float64

# %%
(tourist_data.country.value_counts(normalize=True)*100).plot.bar(figsize=(25,5))
plt.title('percentage disribution of countries')
plt.ylabel('percentage')
# Out:
# Text(0, 0.5, 'percentage')

# %%
tourist_data.travel_with.value_counts()
# Out:
# Alone                  1265
# Spouse                 1005
# Friends/Relatives       895
# Spouse and Children     368
# Children                162
# Name: travel_with, dtype: int64

# %%
tourist_data.travel_with.value_counts().plot.bar(figsize=(10,5))
plt.title('frequency distribution of travel with')
plt.ylabel('frequency')
plt.xlabel('travel with')
# Out:
# Text(0.5, 0, 'travel with')

# %%
tourist_data.travel_with.value_counts(normalize=True)*100
# Out:
# Alone                  34.235453
# Spouse                 27.198917
# Friends/Relatives      24.221922
# Spouse and Children     9.959405
# Children                4.384303
# Name: travel_with, dtype: float64

# %%
(tourist_data.travel_with.value_counts(normalize=True)*100).plot.bar(figsize=(10,5))
plt.title('percentage disribution of travel with')
plt.ylabel('percentage')
plt.xlabel('travel with')
# Out:
# Text(0.5, 0, 'travel with')

# %%
tourist_data.purpose.value_counts()
# Out:
# Leisure and Holidays              2840
# Business                           671
# Visiting Friends and Relatives     633
# Meetings and Conference            312
# Volunteering                       138
# Other                              128
# Scientific and Academic             87
# Name: purpose, dtype: int64

# %%
tourist_data.purpose.value_counts(normalize=True)*100
# Out:
# Leisure and Holidays              59.055937
# Business                          13.953005
# Visiting Friends and Relatives    13.162820
# Meetings and Conference            6.487835
# Volunteering                       2.869619
# Other                              2.661676
# Scientific and Academic            1.809108
# Name: purpose, dtype: float64

# %%
tourist_data.purpose.value_counts().plot.bar(figsize=(10,5))
plt.title('frequency distribution of purpose category')
plt.ylabel('frequency')
plt.xlabel('purpose category')
# Out:
# Text(0.5, 0, 'purpose category')

# %%
(tourist_data.purpose.value_counts(normalize=True)*100).plot.bar(figsize=(10,5))
plt.title('percentage distribution of purpose')
plt.ylabel('percentage')
plt.xlabel('purpose category')
# Out:
# Text(0.5, 0, 'purpose category')

# %%
tourist_data.main_activity.value_counts()
# Out:
# Wildlife tourism            2259
# Beach tourism               1025
# Hunting tourism              457
# Conference tourism           367
# Cultural tourism             359
# Mountain climbing            234
# business                      58
# Bird watching                 37
# Diving and Sport Fishing      13
# Name: main_activity, dtype: int64

# %%
tourist_data.main_activity.value_counts().plot.bar(figsize=(10,5))
plt.title('frequency distribution of main activity')
plt.ylabel('frequency')
plt.xlabel('main activity')
plt.grid()

# %%
tourist_data.main_activity.value_counts(normalize=True)*100
# Out:
# Wildlife tourism            46.974423
# Beach tourism               21.314203
# Hunting tourism              9.503015
# Conference tourism           7.631524
# Cultural tourism             7.465169
# Mountain climbing            4.865876
# business                     1.206072
# Bird watching                0.769391
# Diving and Sport Fishing     0.270326
# Name: main_activity, dtype: float64

# %%
(tourist_data.main_activity.value_counts(normalize=True)*100).plot.bar(figsize=(10,5))
plt.title('percentage distribution of main activity')
plt.ylabel('percentage')
plt.xlabel('main activity')
plt.grid()
